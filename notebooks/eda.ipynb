# %%
import matplotlib.pyplot as plt
import os
import cv2

data_path = r"D:\Project\Project data set\chest_xray\train\PNEUMONIA"
sample_image = cv2.imread(os.path.join(data_path, os.listdir(data_path)[0]))
plt.imshow(cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB))
plt.title("Sample Image from Pneumonia Dataset")
plt.axis("off")
plt.show()
